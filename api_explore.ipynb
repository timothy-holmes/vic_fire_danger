# %%
import json
import requests

cookies = {
    '_gcl_au': '1.1.143843960.1707732045',
    '_fbp': 'fb.3.1707732045368.414798629',
    'cfafirsttime': 'false',
    '_hjSessionUser_2759129': 'eyJpZCI6ImI4ZmMzZGU4LTlhZWMtNTViYy04MmU0LWFiNzhhNzJkYWRhNSIsImNyZWF0ZWQiOjE3MDc3MzIwNDYyOTcsImV4aXN0aW5nIjp0cnVlfQ==',
    'cfalocation': 'Woodend VIC 3442, Australia',
    'cfalat': '-37.3568266',
    'cfalon': '144.5273723',
    'cfasuburb': 'Woodend',
    'cfastate': 'VIC',
    'cfapostal': '3442',
    'cfacountry': 'Australia',
    'cfalocation': 'Woodend VIC 3442, Australia',
    'cfalon': '144.5273723',
    'cfalat': '-37.3568266',
    'cfasuburb': 'Woodend',
    'cfastate': 'VIC',
    'cfapostal': '3442',
    'cfacountry': 'Australia',
    'cfaFindWithInUseDefault': 'False',
    'ASP.NET_SessionId': 'bntfp42bxsd2yuosnmzz5st5',
    '__AntiXsrfToken': 'c08661e3d2024734933db11956106279',
    '_gid': 'GA1.4.354397308.1709320459',
    '_hjSession_2759129': 'eyJpZCI6IjJjOTllODViLTQxODYtNDhiZC04NDVjLTRjZGVhMTA2MWQ5ZSIsImMiOjE3MDkzMjA0NjE0MjQsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
    '_gat_UA-1847174-1': '1',
    '_gat_gtag_UA_1847174_1': '1',
    '_ga': 'GA1.4.279794893.1707732046',
    '_ga_4Y54F18WBL': 'GS1.1.1709320458.9.1.1709320629.42.0.0',
}

headers = {
    'authority': 'www.cfa.vic.gov.au',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'en-AU,en;q=0.9,en-GB-oxendict;q=0.8,en-GB;q=0.7,en-US;q=0.6',
    'content-type': 'application/json; charset=UTF-8',
    # 'cookie': '_gcl_au=1.1.143843960.1707732045; _fbp=fb.3.1707732045368.414798629; cfafirsttime=false; _hjSessionUser_2759129=eyJpZCI6ImI4ZmMzZGU4LTlhZWMtNTViYy04MmU0LWFiNzhhNzJkYWRhNSIsImNyZWF0ZWQiOjE3MDc3MzIwNDYyOTcsImV4aXN0aW5nIjp0cnVlfQ==; cfalocation=Woodend VIC 3442, Australia; cfalat=-37.3568266; cfalon=144.5273723; cfasuburb=Woodend; cfastate=VIC; cfapostal=3442; cfacountry=Australia; cfalocation=Woodend VIC 3442, Australia; cfalon=144.5273723; cfalat=-37.3568266; cfasuburb=Woodend; cfastate=VIC; cfapostal=3442; cfacountry=Australia; cfaFindWithInUseDefault=False; ASP.NET_SessionId=bntfp42bxsd2yuosnmzz5st5; __AntiXsrfToken=c08661e3d2024734933db11956106279; _gid=GA1.4.354397308.1709320459; _hjSession_2759129=eyJpZCI6IjJjOTllODViLTQxODYtNDhiZC04NDVjLTRjZGVhMTA2MWQ5ZSIsImMiOjE3MDkzMjA0NjE0MjQsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _gat_UA-1847174-1=1; _gat_gtag_UA_1847174_1=1; _ga=GA1.4.279794893.1707732046; _ga_4Y54F18WBL=GS1.1.1709320458.9.1.1709320629.42.0.0',
    'origin': 'https://www.cfa.vic.gov.au',
    'referer': 'https://www.cfa.vic.gov.au/warnings-restrictions/fire-bans-ratings-and-restrictions/total-fire-bans-fire-danger-ratings/central-fire-district',
    'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

json_data = {
    'AdminEmailAddress': 'digitalworkflow@cfa.vic.gov.au',
}

response = requests.post('https://www.cfa.vic.gov.au/api/cfa/location/view/', cookies=cookies, headers=headers, json=json_data)
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "PlaceName": "Woodend VIC 3442, Australia",
#     "State": "VIC",
#     "PostalCode": "3442",
#     "Country": "Australia",
#     "Latitude": "-37.3568266",
#     "Longitude": "144.5273723",
#     "Suburb": "Woodend",
#     "Flag": true,
#     "AdminEmailAddress": "",
#     "FireBansAndRatingsDistrictWrapper": [
#         {
#             "IssueDate": "2024-03-02T00:00:00",
#             "IssueAt": "2024-03-02T05:30:00",
#             "ForeCastInformation": "Today, Sat, 2 Mar 2024 is not currently a day of Total Fire Ban.",
#             "DistrictName": "Central",
#             "DistrictData": "NO - RESTRICTIONS MAY APPLY",
#             "DistrictRating": "MODERATE",
#             "Status": "N",
#             "ArticleURL": "/warnings-restrictions/total-fire-bans-and-ratings/central-fire-district",
#             "FDPArea": null,
#             "AdminEmailAddress": null,
#             "WSFireRestrictionsResponse": [
#                 {
#                     "name": "BALLARAT",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Ballarat",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BANYULE",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Banyule",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BASS COAST",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Bass coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BOROUGH OF QUEENSCLIFFE",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Borough of queenscliffe",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CARDINIA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Cardinia",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CASEY",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Casey",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRANKSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Frankston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRENCH ISLAND",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "French island",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GOLDEN PLAINS",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Golden plains",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER DANDENONG",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater dandenong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER GEELONG",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater geelong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HEPBURN",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hepburn",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HUME",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hume",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KINGSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Kingston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KNOX",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Knox",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MACEDON RANGES",
#                     "dtRestrictionStart": "2023-11-27T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Macedon ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MANNINGHAM",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Manningham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MAROONDAH",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Maroondah",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MELTON",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Melton",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MOORABOOL",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Moorabool",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MORNINGTON PENINSULA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Mornington peninsula",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "NILLUMBIK",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Nillumbik",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "SURF COAST",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Surf coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WHITTLESEA",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Whittlesea",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WYNDHAM",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Wyndham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "YARRA RANGES",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Yarra ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 }
#             ]
#         },
#         {
#             "IssueDate": "2024-03-03T00:00:00",
#             "IssueAt": "2024-03-02T05:30:00",
#             "ForeCastInformation": "Tomorrow, Sun, 3 Mar 2024 is not currently a day of Total Fire Ban.",
#             "DistrictName": "Central",
#             "DistrictData": "NO - RESTRICTIONS MAY APPLY",
#             "DistrictRating": "MODERATE",
#             "Status": "N",
#             "ArticleURL": "/warnings-restrictions/total-fire-bans-and-ratings/central-fire-district",
#             "FDPArea": null,
#             "AdminEmailAddress": null,
#             "WSFireRestrictionsResponse": [
#                 {
#                     "name": "BALLARAT",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Ballarat",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BANYULE",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Banyule",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BASS COAST",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Bass coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BOROUGH OF QUEENSCLIFFE",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Borough of queenscliffe",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CARDINIA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Cardinia",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CASEY",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Casey",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRANKSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Frankston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRENCH ISLAND",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "French island",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GOLDEN PLAINS",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Golden plains",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER DANDENONG",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater dandenong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER GEELONG",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater geelong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HEPBURN",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hepburn",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HUME",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hume",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KINGSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Kingston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KNOX",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Knox",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MACEDON RANGES",
#                     "dtRestrictionStart": "2023-11-27T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Macedon ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MANNINGHAM",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Manningham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MAROONDAH",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Maroondah",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MELTON",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Melton",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MOORABOOL",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Moorabool",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MORNINGTON PENINSULA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Mornington peninsula",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "NILLUMBIK",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Nillumbik",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "SURF COAST",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Surf coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WHITTLESEA",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Whittlesea",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WYNDHAM",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Wyndham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "YARRA RANGES",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Yarra ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 }
#             ]
#         },
#         {
#             "IssueDate": "2024-03-04T00:00:00",
#             "IssueAt": "2024-03-02T05:30:00",
#             "ForeCastInformation": "Mon, 4 Mar 2024 is not currently a day of Total Fire Ban.",
#             "DistrictName": "Central",
#             "DistrictData": "NO - RESTRICTIONS MAY APPLY",
#             "DistrictRating": "MODERATE",
#             "Status": "N",
#             "ArticleURL": "/warnings-restrictions/total-fire-bans-and-ratings/central-fire-district",
#             "FDPArea": null,
#             "AdminEmailAddress": null,
#             "WSFireRestrictionsResponse": [
#                 {
#                     "name": "BALLARAT",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Ballarat",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BANYULE",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Banyule",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BASS COAST",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Bass coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BOROUGH OF QUEENSCLIFFE",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Borough of queenscliffe",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CARDINIA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Cardinia",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CASEY",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Casey",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRANKSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Frankston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRENCH ISLAND",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "French island",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GOLDEN PLAINS",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Golden plains",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER DANDENONG",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater dandenong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER GEELONG",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater geelong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HEPBURN",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hepburn",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HUME",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hume",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KINGSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Kingston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KNOX",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Knox",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MACEDON RANGES",
#                     "dtRestrictionStart": "2023-11-27T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Macedon ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MANNINGHAM",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Manningham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MAROONDAH",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Maroondah",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MELTON",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Melton",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MOORABOOL",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Moorabool",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MORNINGTON PENINSULA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Mornington peninsula",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "NILLUMBIK",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Nillumbik",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "SURF COAST",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Surf coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WHITTLESEA",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Whittlesea",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WYNDHAM",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Wyndham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "YARRA RANGES",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Yarra ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 }
#             ]
#         },
#         {
#             "IssueDate": "2024-03-05T00:00:00",
#             "IssueAt": "2024-03-02T05:30:00",
#             "ForeCastInformation": "Tue, 5 Mar 2024 is not currently a day of Total Fire Ban.",
#             "DistrictName": "Central",
#             "DistrictData": "NO - RESTRICTIONS MAY APPLY",
#             "DistrictRating": "HIGH",
#             "Status": "N",
#             "ArticleURL": "/warnings-restrictions/total-fire-bans-and-ratings/central-fire-district",
#             "FDPArea": null,
#             "AdminEmailAddress": null,
#             "WSFireRestrictionsResponse": [
#                 {
#                     "name": "BALLARAT",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Ballarat",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BANYULE",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Banyule",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BASS COAST",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Bass coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BOROUGH OF QUEENSCLIFFE",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Borough of queenscliffe",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CARDINIA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Cardinia",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CASEY",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Casey",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRANKSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Frankston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRENCH ISLAND",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "French island",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GOLDEN PLAINS",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Golden plains",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER DANDENONG",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater dandenong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER GEELONG",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater geelong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HEPBURN",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hepburn",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HUME",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hume",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KINGSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Kingston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KNOX",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Knox",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MACEDON RANGES",
#                     "dtRestrictionStart": "2023-11-27T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Macedon ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MANNINGHAM",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Manningham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MAROONDAH",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Maroondah",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MELTON",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Melton",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MOORABOOL",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Moorabool",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MORNINGTON PENINSULA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Mornington peninsula",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "NILLUMBIK",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Nillumbik",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "SURF COAST",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Surf coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WHITTLESEA",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Whittlesea",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WYNDHAM",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Wyndham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "YARRA RANGES",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Yarra ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 }
#             ]
#         },
#         {
#             "IssueDate": "2024-03-06T00:00:00",
#             "IssueAt": "1900-01-01T00:00:00",
#             "ForeCastInformation": "Wed, 6 Mar 2024 is not currently a day of Total Fire Ban.",
#             "DistrictName": "Central",
#             "DistrictData": "NO - RESTRICTIONS MAY APPLY",
#             "DistrictRating": "",
#             "Status": "N",
#             "ArticleURL": "/warnings-restrictions/total-fire-bans-and-ratings/central-fire-district",
#             "FDPArea": null,
#             "AdminEmailAddress": null,
#             "WSFireRestrictionsResponse": [
#                 {
#                     "name": "BALLARAT",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Ballarat",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BANYULE",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Banyule",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BASS COAST",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Bass coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "BOROUGH OF QUEENSCLIFFE",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Borough of queenscliffe",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CARDINIA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Cardinia",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "CASEY",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Casey",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRANKSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Frankston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "FRENCH ISLAND",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "French island",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GOLDEN PLAINS",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Golden plains",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER DANDENONG",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater dandenong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "GREATER GEELONG",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Greater geelong",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HEPBURN",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hepburn",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "HUME",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Hume",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KINGSTON",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Kingston",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "KNOX",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Knox",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MACEDON RANGES",
#                     "dtRestrictionStart": "2023-11-27T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Macedon ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MANNINGHAM",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Manningham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MAROONDAH",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Maroondah",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MELTON",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Melton",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MOORABOOL",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Moorabool",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "MORNINGTON PENINSULA",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Mornington peninsula",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "NILLUMBIK",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Nillumbik",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "SURF COAST",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Surf coast",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WHITTLESEA",
#                     "dtRestrictionStart": "2023-12-04T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Whittlesea",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "WYNDHAM",
#                     "dtRestrictionStart": "2023-11-20T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Wyndham",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 },
#                 {
#                     "name": "YARRA RANGES",
#                     "dtRestrictionStart": "2023-12-18T00:00:00",
#                     "dtRestrictionStop": "2024-05-01T00:00:00",
#                     "friendlyName": "Yarra ranges",
#                     "status": "ACTIVE",
#                     "notActiveStatusMessage": "",
#                     "fdrDistrict": "Central"
#                 }
#             ]
#         }
#     ],
#     "FireDangerPeriodBoundaryResponse": {
#         "objectIdFieldName": "OBJECTID",
#         "uniqueIdField": {
#             "name": "OBJECTID",
#             "isSystemMaintained": true
#         },
#         "globalIdFieldName": "",
#         "geometryType": "esriGeometryPolygon",
#         "spatialReference": {
#             "wkid": 4283,
#             "latestWkid": 4283
#         },
#         "fields": [
#             {
#                 "name": "fdp_name",
#                 "type": "esriFieldTypeString",
#                 "alias": "fdp_name",
#                 "sqlType": "sqlTypeOther",
#                 "length": 100,
#                 "domain": null,
#                 "defaultValue": null
#             },
#             {
#                 "name": "tfb_dstrct",
#                 "type": "esriFieldTypeString",
#                 "alias": "tfb_dstrct",
#                 "sqlType": "sqlTypeOther",
#                 "length": 100,
#                 "domain": null,
#                 "defaultValue": null
#             },
#             {
#                 "name": "fdp_no",
#                 "type": "esriFieldTypeSmallInteger",
#                 "alias": "fdp_no",
#                 "sqlType": "sqlTypeOther",
#                 "length": 0,
#                 "domain": null,
#                 "defaultValue": null
#             }
#         ],
#         "features": [
#             {
#                 "attributes": {
#                     "fdp_name": "Macedon Ranges",
#                     "tfb_dstrct": "Central",
#                     "fdp_no": 402
#                 }
#             }
#         ]
#     }
# }

# %%
from collections import defaultdict

forecasts = defaultdict(dict)

for f in response.json().get('FireBansAndRatingsDistrictWrapper',{}):
    forecasts[f['IssueDate']][f['IssueAt']] = {'Status': f['Status'], 'DistrictRating': f['DistrictRating']}

print(json.dumps(forecasts, indent=4))
# Out:
# {
#     "2024-03-02T00:00:00": {
#         "2024-03-02T05:30:00": {
#             "Status": "N",
#             "DistrictRating": "MODERATE"
#         }
#     },
#     "2024-03-03T00:00:00": {
#         "2024-03-02T05:30:00": {
#             "Status": "N",
#             "DistrictRating": "MODERATE"
#         }
#     },
#     "2024-03-04T00:00:00": {
#         "2024-03-02T05:30:00": {
#             "Status": "N",
#             "DistrictRating": "MODERATE"
#         }
#     },
#     "2024-03-05T00:00:00": {
#         "2024-03-02T05:30:00": {
#             "Status": "N",
#             "DistrictRating": "HIGH"
#         }
#     },
#     "2024-03-06T00:00:00": {
#         "1900-01-01T00:00:00": {
#             "Status": "N",
#             "DistrictRating": ""
#         }
#     }
# }

# %%
import json

import requests

def main():
    cookies = {
        '_gcl_au': '1.1.143843960.1707732045',
        '_fbp': 'fb.3.1707732045368.414798629',
        'cfafirsttime': 'false',
        '_hjSessionUser_2759129': 'eyJpZCI6ImI4ZmMzZGU4LTlhZWMtNTViYy04MmU0LWFiNzhhNzJkYWRhNSIsImNyZWF0ZWQiOjE3MDc3MzIwNDYyOTcsImV4aXN0aW5nIjp0cnVlfQ==',
        'cfalocation': 'Woodend VIC 3442, Australia',
        'cfalat': '-37.3568266',
        'cfalon': '144.5273723',
        'cfasuburb': 'Woodend',
        'cfastate': 'VIC',
        'cfapostal': '3442',
        'cfacountry': 'Australia',
        'cfalocation': 'Woodend VIC 3442, Australia',
        'cfalon': '144.5273723',
        'cfalat': '-37.3568266',
        'cfasuburb': 'Woodend',
        'cfastate': 'VIC',
        'cfapostal': '3442',
        'cfacountry': 'Australia',
        'cfaFindWithInUseDefault': 'False',
        'ASP.NET_SessionId': 'bntfp42bxsd2yuosnmzz5st5',
        '__AntiXsrfToken': 'c08661e3d2024734933db11956106279',
        '_gid': 'GA1.4.354397308.1709320459',
        '_hjSession_2759129': 'eyJpZCI6IjJjOTllODViLTQxODYtNDhiZC04NDVjLTRjZGVhMTA2MWQ5ZSIsImMiOjE3MDkzMjA0NjE0MjQsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=',
        '_gat_UA-1847174-1': '1',
        '_gat_gtag_UA_1847174_1': '1',
        '_ga': 'GA1.4.279794893.1707732046',
        '_ga_4Y54F18WBL': 'GS1.1.1709320458.9.1.1709320629.42.0.0',
    }

    headers = {
        'authority': 'www.cfa.vic.gov.au',
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'en-AU,en;q=0.9,en-GB-oxendict;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'content-type': 'application/json; charset=UTF-8',
        # 'cookie': '_gcl_au=1.1.143843960.1707732045; _fbp=fb.3.1707732045368.414798629; cfafirsttime=false; _hjSessionUser_2759129=eyJpZCI6ImI4ZmMzZGU4LTlhZWMtNTViYy04MmU0LWFiNzhhNzJkYWRhNSIsImNyZWF0ZWQiOjE3MDc3MzIwNDYyOTcsImV4aXN0aW5nIjp0cnVlfQ==; cfalocation=Woodend VIC 3442, Australia; cfalat=-37.3568266; cfalon=144.5273723; cfasuburb=Woodend; cfastate=VIC; cfapostal=3442; cfacountry=Australia; cfalocation=Woodend VIC 3442, Australia; cfalon=144.5273723; cfalat=-37.3568266; cfasuburb=Woodend; cfastate=VIC; cfapostal=3442; cfacountry=Australia; cfaFindWithInUseDefault=False; ASP.NET_SessionId=bntfp42bxsd2yuosnmzz5st5; __AntiXsrfToken=c08661e3d2024734933db11956106279; _gid=GA1.4.354397308.1709320459; _hjSession_2759129=eyJpZCI6IjJjOTllODViLTQxODYtNDhiZC04NDVjLTRjZGVhMTA2MWQ5ZSIsImMiOjE3MDkzMjA0NjE0MjQsInMiOjAsInIiOjAsInNiIjowLCJzciI6MCwic2UiOjAsImZzIjowLCJzcCI6MH0=; _gat_UA-1847174-1=1; _gat_gtag_UA_1847174_1=1; _ga=GA1.4.279794893.1707732046; _ga_4Y54F18WBL=GS1.1.1709320458.9.1.1709320629.42.0.0',
        'origin': 'https://www.cfa.vic.gov.au',
        'referer': 'https://www.cfa.vic.gov.au/warnings-restrictions/fire-bans-ratings-and-restrictions/total-fire-bans-fire-danger-ratings/central-fire-district',
        'sec-ch-ua': '"Not A(Brand";v="99", "Google Chrome";v="121", "Chromium";v="121"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest',
    }

    json_data = {
        'AdminEmailAddress': 'digitalworkflow@cfa.vic.gov.au',
    }

    response = requests.post('https://www.cfa.vic.gov.au/api/cfa/location/view/', cookies=cookies, headers=headers, json=json_data)

    new_forecasts = {}

    STATUS_MAP = {
        'status': {'N': 0, 'Y': 1},
        'rating': {'NO RATING': 0, '': 0,'MODERATE': 1, 'HIGH': 2, 'EXTREME': 3, 'CATASTROPHIC': 4}
    }

    new_forecasts = [
        {'date': f['IssueDate'], 'issued_at': f['IssueAt'], 'status': STATUS_MAP['status'][f['Status']], 'rating': STATUS_MAP['rating'][f['DistrictRating']]}
        for f in response.json()['FireBansAndRatingsDistrictWrapper']
    ]

    return new_forecasts

# %%
new_forecasts = main()

# %%
for f in sorted(new_forecasts, key=lambda x: x['date']):
    print(f)
# Out:
# {'date': '2024-03-10T00:00:00', 'issued_at': '2024-03-10T05:30:00', 'status': 0, 'rating': 2}
# {'date': '2024-03-11T00:00:00', 'issued_at': '2024-03-10T05:30:00', 'status': 0, 'rating': 2}
# {'date': '2024-03-12T00:00:00', 'issued_at': '2024-03-10T05:30:00', 'status': 0, 'rating': 1}
# {'date': '2024-03-13T00:00:00', 'issued_at': '2024-03-10T05:30:00', 'status': 0, 'rating': 1}
# {'date': '2024-03-14T00:00:00', 'issued_at': '1900-01-01T00:00:00', 'status': 0, 'rating': 0}

# %%
old_forecasts = json.load(open('forecast_history.json'))
yesterday_history = [f for f in old_forecasts if f['date'] == '2024-03-09T00:00:00']

# %%
for f in sorted(yesterday_history, key=lambda x: x['issued_at']):
    print(sorted(f.items(), key=lambda x: x[0]))
# Out:
# [('date', '2024-03-09T00:00:00'), ('issued_at', '1900-01-01T00:00:00'), ('rating', 0), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-05T16:00:00'), ('rating', 2), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-06T05:30:00'), ('rating', 2), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-06T16:00:00'), ('rating', 2), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-07T05:30:00'), ('rating', 2), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-07T16:00:00'), ('rating', 3), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-08T05:30:00'), ('rating', 3), ('status', 1)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-08T05:30:00'), ('rating', 3), ('status', 0)]
# [('date', '2024-03-09T00:00:00'), ('issued_at', '2024-03-08T16:00:00'), ('rating', 3), ('status', 1)]

# %%
old_forecasts = json.load(open('forecast_history.json'))

for f in old_forecasts:
    f['retrieved_at'] = ''

# %%
json.dump(old_forecasts, open('forecast_history.json', 'w'), indent=4)
